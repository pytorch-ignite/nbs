# %% [markdown]
# # Template Vision Classification by PyTorch-Ignite Code-Generator
#
# Please, run the cell below to execute your code.

# %%
cur_dir = !mkdir pytorch-ignite-template-`date "+%Y%m%d-%H%M%S"` && cd $_ && echo $PWD
# %cd {cur_dir[0]}
# !wget https://raw.githubusercontent.com/pytorch-ignite/nbs/main/nbs/0eca096a-9712-5fb5-8d34-192b82af9947/ignite-template-vision-classification.zip
# !unzip ignite-template-vision-classification.zip
# !pip install -r requirements.txt

# %%
# %cd {cur_dir[0]}
# !python main.py config.yaml
