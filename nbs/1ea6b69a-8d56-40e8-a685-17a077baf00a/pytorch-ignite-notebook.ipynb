# %%
# !wget https://raw.githubusercontent.com/trsvchn-lab/nbs/main/nbs/1ea6b69a-8d56-40e8-a685-17a077baf00a/pytorch-ignite-notebook.zip
# !unzip pytorch-ignite-notebook.zip
# !pip install -r requirements.txt
# !python main.py
