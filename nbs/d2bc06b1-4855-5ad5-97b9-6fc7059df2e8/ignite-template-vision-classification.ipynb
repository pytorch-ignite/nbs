# %% [markdown]
# # Template Vision Classification by PyTorch-Ignite Code-Generator
#
# Please, run the cell below to execute your code.

# %%
# !wget https://raw.githubusercontent.com/pytorch-ignite/nbs/main/nbs/d2bc06b1-4855-5ad5-97b9-6fc7059df2e8/ignite-template-vision-classification.zip
# !unzip ignite-template-vision-classification.zip
# !pip install -r requirements.txt

# %%
# !python main.py #--config-dir=/content/ --config-name=config.yaml
