# %% [markdown]
# # Template Vision Segmentation by PyTorch-Ignite Code-Generator
#
# Please, run the cell below to execute your code.

# %%
# !wget https://raw.githubusercontent.com/trsvchn-lab/nbs/main/nbs/4853d5d5-9f57-4c46-aad9-847a0b3b0ed4/ignite-template-vision-segmentation.zip
# !unzip ignite-template-vision-segmentation.zip
# !pip install -r requirements.txt
# !python main.py
