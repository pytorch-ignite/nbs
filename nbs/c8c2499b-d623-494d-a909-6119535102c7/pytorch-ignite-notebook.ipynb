# %%
# !wget https://raw.githubusercontent.com/trsvchn-lab/nbs/main/nbs/c8c2499b-d623-494d-a909-6119535102c7/pytorch-ignite-notebook.zip!unzip pytorch-ignite-notebook.zip!pip install -r requirements.txt!python main.py
