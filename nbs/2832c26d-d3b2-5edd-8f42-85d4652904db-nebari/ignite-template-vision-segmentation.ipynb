# %% [markdown]
# # Template Vision Segmentation by PyTorch-Ignite Code-Generator
#
# Please, run the cell below to execute your code.

# %%
cur_dir = !mkdir pytorch-ignite-template-`date "+%Y%m%d-%H%M%S"` && cd $_ && echo $PWD
# %cd {cur_dir[0]}
# !wget https://raw.githubusercontent.com/pytorch-ignite/nbs/main/nbs/2832c26d-d3b2-5edd-8f42-85d4652904db/ignite-template-vision-segmentation.zip
# !unzip ignite-template-vision-segmentation.zip
# !pip install -r requirements.txt

# %%
# !python -c "from data import download_datasets; download_datasets('./')"

# %%
# %cd {cur_dir[0]}
# !python main.py config.yaml
