# %% [markdown]
# # Template Vision Dcgan by PyTorch-Ignite Code-Generator
#
# Please, run the cell below to execute your code.

# %%
cur_dir = !mkdir pytorch-ignite-template-`date "+%Y%m%d-%H%M%S"` && cd $_ && echo $PWD
# %cd {cur_dir[0]}
# !wget https://raw.githubusercontent.com/pytorch-ignite/nbs/main/nbs/34e5e54e-ca09-5915-9d4a-6aa8cfb1ecde/ignite-template-vision-dcgan.zip
# !unzip ignite-template-vision-dcgan.zip
# !pip install -r requirements.txt

# %%
# %cd {cur_dir[0]}
# !python main.py config.yaml
