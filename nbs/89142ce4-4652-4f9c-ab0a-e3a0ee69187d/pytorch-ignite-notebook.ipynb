# %%
# !wget https://raw.githubusercontent.com/trsvchn-lab/nbs/main/nbs/89142ce4-4652-4f9c-ab0a-e3a0ee69187d/pytorch-ignite-notebook.zip
# !unzip pytorch-ignite-notebook.zip
# !pip install -r requirements.txt
# !python main.py
