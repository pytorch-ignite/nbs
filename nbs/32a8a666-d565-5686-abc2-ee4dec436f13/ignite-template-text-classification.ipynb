# %% [markdown]
# # Template Text Classification by PyTorch-Ignite Code-Generator
#
# Please, run the cell below to execute your code.

# %%
# !wget https://raw.githubusercontent.com/pytorch-ignite/nbs/main/nbs/32a8a666-d565-5686-abc2-ee4dec436f13/ignite-template-text-classification.zip
# !unzip ignite-template-text-classification.zip
# !pip install -r requirements.txt

# %%
# !python main.py config.yaml
